# %% [markdown]
# # Perform feature transformation:
#
# **Transformation of feature**
#
# why transformation of feature are required?
#
# 1.Linear Regression -- Gradient Descent--Global Minima
#
# 2.Algorithms like KNN, K-Means , Hierarichal clustering--eucledian distance
#
# Every point has some vectors and directions
#
# Deep Learning Techniques( standardization,scaling)
#
# 1.ANN-->Global Minima Gradient
#
# 2.CNN
#
# 3.RNN
#
# **Standardization(why?)**
#
# standardization comes into picture when features of input data set have large difference between their ranges,
# or simply when they are measured in different measurement units(eg. pounds , meters , miles...etc)
#
# I try to bring all thevariable or features to a similar scale. standardization means centering the variable at zero.
#
# z=(x- x_mean)/std

# %%
import numpy as np
import pandas as pd

dataset=pd.read_csv('adult.csv')
dataset=dataset.head(10)
dataset
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
import pandas as pd
dataset=pd.read_csv('adult.csv')
coln_used=(['age','educational-num','hours-per-week','income'])
dataset.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
dataset['age'].fillna(dataset.age.median(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# **independent and dependent feature**

# %%
x=dataset.iloc[:,1:]
y=dataset.iloc[:,0]

# %%
x
# Out:
#           workclass  fnlwgt     education  educational-num  \
# 0           Private  226802          11th                7
# 1           Private   89814       HS-grad                9
# 2         Local-gov  336951    Assoc-acdm               12
# 3           Private  160323  Some-college               10
# 4                 ?  103497  Some-college               10
# ...             ...     ...           ...              ...
# 48837       Private  257302    Assoc-acdm               12
# 48838       Private  154374       HS-grad                9
# 48839       Private  151910       HS-grad                9
# 48840       Private  201490       HS-grad                9
# 48841  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33, random_state=42)

# %%
x_train
# Out:
#        workclass  fnlwgt     education  educational-num  \
# 5551     Private  154117       HS-grad                9
# 36721    Private  440607     Preschool                1
# 2638   Local-gov  197822     Bachelors               13
# 36214    Private  211601  Some-college               10
# 27010  Local-gov  121998  Some-college               10
# ...          ...     ...           ...              ...
# 11284    Private  635913       HS-grad                9
# 44732    Private  107624  Some-college               10
# 38158    Private  250135  Some-college               10
# 860    State-gov   96652     Assoc-voc               11
# 15795    Private  176118       Masters               14
#
#               marital-status       occupation    relationship   race  gender  \
# 5551               Separated     Craft-repair  Other-relative  White  Female
# 36721     Married-civ-spouse   Prof-specialty         Husband  Other    Male
# ...

# %% [markdown]
# **standarisation : we use the standardscaler from sklearn library**

# %%
from sklearn.preprocessing import StandardScaler

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.DataFrame({
    'Income': [40000, 50000, 60000, 65000,45000],
    'Age': [25, 38, 28, 44, 18],
    'Occupation': ['Machine-op-inspct','Farming-fishing','Protective-serv','Machine-op-inspct','?']
})

# %%
df_scaled = df.copy()
col_names = ['Income', 'Age']
features = df_scaled[col_names]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

df_scaled[col_names] = scaler.fit_transform(features.values)
df_scaled
# Out:
#      Income       Age         Occupation
# 0 -1.293993 -0.603023  Machine-op-inspct
# 1 -0.215666  0.796851    Farming-fishing
# 2  0.862662 -0.279975    Protective-serv
# 3  1.401826  1.442947  Machine-op-inspct
# 4 -0.754829 -1.356801                  ?

# %%
df_scaled.describe()
# Out:
#              Income           Age
# count  5.000000e+00  5.000000e+00
# mean   2.220446e-17 -1.332268e-16
# std    1.118034e+00  1.118034e+00
# min   -1.293993e+00 -1.356801e+00
# 25%   -7.548294e-01 -6.030227e-01
# 50%   -2.156655e-01 -2.799748e-01
# 75%    8.626622e-01  7.968514e-01
# max    1.401826e+00  1.442947e+00

# %% [markdown]
# **step9**

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
iris=datasets.load_iris()

# %%
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
target='income'
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
x=iris.data
y=iris.target

# %%
x.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
clf=RandomForestClassifier()
clf.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
print(clf.feature_importances_)
# Out:
# [0.10269424 0.02612034 0.42979497 0.44139045]

# %%
x[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
print(clf.predict([[5.1, 3.5, 1.4, 0.2]]))
# Out:
# [0]

# %%
print(clf.predict(x[[0]]))
# Out:
# [0]

# %%
clf.fit(iris.data,iris.target_names[iris.target])
# Out:
# RandomForestClassifier()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape,y_train.shape
# Out:
# ((120, 4), (120,))

# %%
x_test.shape,y_test.shape
# Out:
# ((30, 4), (30,))

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print(clf.predict([[5.1, 3.5, 1.4, 0.2]]))
# Out:
# [0]

# %%
print(clf.predict_proba([[5.1,3.5,1.4,0.2]]))
# Out:
# [[1. 0. 0.]]

# %%
print(clf.predict(x_test))
# Out:
# [1 0 0 0 0 0 1 0 1 1 2 1 2 2 0 2 2 1 2 2 0 2 1 0 2 0 1 0 1 2]
